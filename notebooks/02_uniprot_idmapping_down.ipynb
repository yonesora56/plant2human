# %%
import time
import polars as pl
import requests
import json
import pathlib
from typing import List, Tuple
from unipressed import IdMappingClient

# %%
gene_id_tsv = "../Data/Data_HN5_genelist_rice_2402/HN5_genes_down_rice.tsv"
query_db = "Ensembl_Genomes"
target_db = "UniProtKB"
json_dir = "../out/rice_down/rice_down_afinfo"

# %% [markdown]
# ## 1. UniProt ID mapping step

# %%
def chunk_list(lst: List, chunk_size: int) -> List[List]:
    """Split a gene list into chunks"""
    return [lst[i:i + chunk_size] for i in range(0, len(lst), chunk_size)]

# %%
def batch_id_mapping(from_db: str, to_db: str, ids: List[str], chunk_size: int = 100) -> Tuple[pl.DataFrame, List[str]]:
    """function for batch id mapping"""
    all_results = []
    all_unmapped = []
    chunked_ids = chunk_list(ids, chunk_size)

    for i, chunk in enumerate(chunked_ids):
        print(f"Processing chunk {i+1}/{len(chunked_ids)}...")
        
        # create request and run
        request = IdMappingClient.submit(source=from_db, dest=to_db, ids=chunk)
        
        # process results
        chunk_results = list(request.each_result())
        mapped_results = [{"from": item["from"], "to": item["to"]} for item in chunk_results]
        all_results.extend(mapped_results)

        # record unmapped ids
        mapped_ids = set(item["from"] for item in mapped_results)
        unmapped = [id for id in chunk if id not in mapped_ids]
        all_unmapped.extend(unmapped)

        # avoid API rate limit
        time.sleep(1)

    # convert results to DataFrame
    final_df = pl.DataFrame(all_results)
    return final_df, all_unmapped

# %%
gene_ids = pl.read_csv(
    gene_id_tsv,
    separator='\t'
).get_column("From").to_list()

mapped_df, unmapped_ids = batch_id_mapping(
    query_db,
    target_db,
    gene_ids
)

display(mapped_df)
display(unmapped_ids)
# Out:
# Processing chunk 1/4...
# Processing chunk 2/4...
# Processing chunk 3/4...
# Processing chunk 4/4...
# shape: (630, 2)
# ┌──────────────┬────────────┐
# │ from         ┆ to         │
# │ ---          ┆ ---        │
# │ str          ┆ str        │
# ╞══════════════╪════════════╡
# │ Os03g0859100 ┆ A0A0P0W5R9 │
# │ Os03g0859100 ┆ A0A8J8XPT0 │
# │ Os03g0859100 ┆ A0A8J8YIZ0 │
# │ Os03g0859100 ┆ A3APY6     │
# │ Os03g0859100 ┆ A3APY7     │
# │ …            ┆ …          │
# │ Os03g0307200 ┆ Q10MI9     │
# │ Os07g0142200 ┆ A0A0P0X2Q0 │
# │ Os07g0142200 ┆ Q8H4K4     │
# │ Os03g0307300 ┆ Q0DSH9     │
# │ Os03g0307300 ┆ H9BE58     │
# └──────────────┴────────────┘
# ['Os01g0192900',
#  'Os09g0249750',
#  'Os12g0116800',
#  'Os10g0556000',
#  'Os04g0578600',
#  'Os07g0142100']

# %%
mapped_df2 = mapped_df.rename(
    {
        "from": "From",
        "to": "UniProt Accession"
    }
)

display(mapped_df2)
# Out:
# shape: (630, 2)
# ┌──────────────┬───────────────────┐
# │ From         ┆ UniProt Accession │
# │ ---          ┆ ---               │
# │ str          ┆ str               │
# ╞══════════════╪═══════════════════╡
# │ Os03g0859100 ┆ A0A0P0W5R9        │
# │ Os03g0859100 ┆ A0A8J8XPT0        │
# │ Os03g0859100 ┆ A0A8J8YIZ0        │
# │ Os03g0859100 ┆ A3APY6            │
# │ Os03g0859100 ┆ A3APY7            │
# │ …            ┆ …                 │
# │ Os03g0307200 ┆ Q10MI9            │
# │ Os07g0142200 ┆ A0A0P0X2Q0        │
# │ Os07g0142200 ┆ Q8H4K4            │
# │ Os03g0307300 ┆ Q0DSH9            │
# │ Os03g0307300 ┆ H9BE58            │
# └──────────────┴───────────────────┘

# %% [markdown]
# ## 2. UniProt re-mapping

# %%
def fetch_uniprot_data(ensembl_ids: List[str]) -> pl.DataFrame:
    results = []

    for id in ensembl_ids:
        print(f"Processing {id}...")
        url = (
            f"https://rest.uniprot.org/uniprotkb/search?"
            f"query=gene:{id}&format=json"
        )
        response = requests.get(url)
        
        if response.status_code == 200:
            data = json.loads(response.text)
            for item in data.get('results', []):
                primary_accession = item.get('primaryAccession', '')
                secondary_accessions = item.get('secondaryAccessions', [])
                all_accessions = [primary_accession] + secondary_accessions
                
                for accession in all_accessions:
                    entry = {
                        "From": id,
                        "UniProt Accession": accession
                    }
                    
                    # Check if the accession is a match for the gene 
                    # (e.g. Os03g0293000 matches OrderedLocusNames)
                    match_found = False
                    for gene in item.get('genes', []):
                        for locus in gene.get('orderedLocusNames', []):
                            if locus.get('value', '') == id:
                                match_found = True
                                break
                        if match_found:
                            break
                    
                    if match_found:
                        results.append(entry)
        else:
            print(f"Error fetching data for {id}: {response.status_code}")
        
        time.sleep(1)

    return pl.DataFrame(results)

# %%
unmapped_df = fetch_uniprot_data(unmapped_ids)
display(unmapped_df)
# Out:
# Processing Os01g0192900...
# Processing Os09g0249750...
# Processing Os12g0116800...
# Processing Os10g0556000...
# Processing Os04g0578600...
# Processing Os07g0142100...
# shape: (10, 2)
# ┌──────────────┬───────────────────┐
# │ From         ┆ UniProt Accession │
# │ ---          ┆ ---               │
# │ str          ┆ str               │
# ╞══════════════╪═══════════════════╡
# │ Os01g0192900 ┆ A0A0P0UZP7        │
# │ Os01g0192900 ┆ O24220            │
# │ Os01g0192900 ┆ Q9FU17            │
# │ Os09g0249750 ┆ A0A0P0XK13        │
# │ Os12g0116800 ┆ A0A0P0Y6C0        │
# │ Os10g0556000 ┆ A0A0P0XXI3        │
# │ Os04g0578600 ┆ Q0JAT2            │
# │ Os04g0578600 ┆ A0A0P0WE87        │
# │ Os07g0142100 ┆ Q0D8P1            │
# │ Os07g0142100 ┆ A0A0N7KMX3        │
# └──────────────┴───────────────────┘

# %% [markdown]
# ## 3. Concatenate the two dataframes

# %%
id_mapping_df = pl.concat(
    [
        mapped_df2,
        unmapped_df
    ],
    how="vertical_relaxed"
).sort(
    by="From",
    descending=False
)

display(id_mapping_df)
# Out:
# shape: (640, 2)
# ┌──────────────┬───────────────────┐
# │ From         ┆ UniProt Accession │
# │ ---          ┆ ---               │
# │ str          ┆ str               │
# ╞══════════════╪═══════════════════╡
# │ Os01g0105300 ┆ A0A0P0UWX1        │
# │ Os01g0136300 ┆ A0A8J8YJH9        │
# │ Os01g0136300 ┆ Q5ZC68            │
# │ Os01g0137950 ┆ A0A0P0UXR3        │
# │ Os01g0179600 ┆ B7FAP2            │
# │ …            ┆ …                 │
# │ Os12g0610800 ┆ A0A0N7KUC5        │
# │ Os12g0630100 ┆ Q0ILR1            │
# │ Os12g0630100 ┆ Q2QLS8            │
# │ Os12g0630200 ┆ A3CJP3            │
# │ Os12g0630200 ┆ Q2QLS7            │
# └──────────────┴───────────────────┘

# %% [markdown]
# ## 4. Get AlphaFold metadata JSON files

# %%
def get_af_json(dataframe: pl.DataFrame, target_dir: str):
    """
    Get JSON file from AlphaFoldDB
    """
    pathlib.Path(target_dir).mkdir(parents=True, exist_ok=True)
    
    for row in dataframe.iter_rows():
        gene_id = row[0]
        uniprot_id = row[1]
        
        json_file_name = pathlib.Path(target_dir) / f"{gene_id}_{uniprot_id}_info.json"
        
        if json_file_name.exists():
            message_1 = f"{json_file_name} already exists"
            print(message_1)
            continue
        
        request_url = f"https://alphafold.ebi.ac.uk/api/prediction/{uniprot_id}"
        
        try:
            response = requests.get(request_url, headers={"Accept": "application/json"}, timeout=30)
            response.raise_for_status()
            
            if response.text:
                data = json.loads(response.text) # parse json
                if isinstance(data, list) and len(data) > 0:
                    message_2 = f"AlphaFold ID {uniprot_id} found in AlphaFold"
                    print(message_2)
                    with open(json_file_name, 'w') as f:
                        json.dump(data[0], f, indent=4)
                else:
                    message_3 = f"AlphaFold ID {uniprot_id} not found in AlphaFold"
                    print(message_3)
            else:
                message_4 = f"Empty response for AlphaFold ID {uniprot_id}"
                print(message_4)
        except requests.exceptions.RequestException as e:
            message_5 = f"Request failed: {e}"
            print(message_5)
            message_6 = f"AlphaFold ID {uniprot_id} not found in AlphaFold"
            print(message_6)
        time.sleep(5)

# %%
get_af_json(id_mapping_df, json_dir)
# Out:
# ../out/rice_down/rice_down_afinfo/Os01g0105300_A0A0P0UWX1_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A0A8J8YJH9
# AlphaFold ID A0A8J8YJH9 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os01g0136300_Q5ZC68_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0137950_A0A0P0UXR3_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0179600_B7FAP2_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0179600_Q0JQ63_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0192900_A0A0P0UZP7_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0192900_O24220_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0192900_Q9FU17_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A0A8J8YP02
# AlphaFold ID A0A8J8YP02 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os01g0208400_Q8LRI2_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/Q0JPL7
# AlphaFold ID Q0JPL7 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os01g0216000_Q9LHW4_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0220700_A0A0P0V0L5_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0232000_Q9LWR2_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0248300_Q7F7C9_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0248300_Q9XHX6_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A0A979HJQ7
# AlphaFold ID A0A979HJQ7 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os01g0248701_C7IXE8_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0279400_Q5NBS2_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0279400_Q8H6D6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0284500_Q7F731_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0318400_Q0JN80_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0318400_Q7XXQ7_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0329000_A0A0P0V1T5_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0329000_Q0JN44_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0329075_A0A0P0V2D0_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A0A0N7KD00
# AlphaFold ID A0A0N7KD00 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os01g0382000_Q7F1Q9_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0382000_O04000_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0382400_Q7F2N5_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0382400_Q8W084_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0444100_A0A0P0V376_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0495701_A0A0P0V2W9_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0525701_A0A0P0V3I1_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A0A979HLD2
# AlphaFold ID A0A979HLD2 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os01g0550800_Q5JK80_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0591300_A0A0N7KD90_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0591300_A0A0P0V4Q5_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0591300_Q94JC6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0608000_A0A0P0V521_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0608101_A0A0P0V528_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0608101_C7IWA4_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0613500_A0A0P0V569_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0613500_Q9FTI3_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0627400_A0A0P0V5H0_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/Q5ZEB4
# AlphaFold ID Q5ZEB4 not found in AlphaFold
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A0A0P0V5K3
# AlphaFold ID A0A0P0V5K3 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os01g0631800_Q8RZJ7_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0631900_A0A0P0V5L9_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0647200_A0A0P0V5W5_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0655500_A0A0N7KDF8_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0655500_A0A0P0V637_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0655500_Q5SN79_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0660200_O22080_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0660200_Q7F4M8_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A0A979HJ20
# AlphaFold ID A0A979HJ20 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os01g0680650_Q5QLE7_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0689451_A0A0N7KDJ4_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0689451_V9G2Z0_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0696800_A0A0N7KDK3_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A0A8J8XIG2
# AlphaFold ID A0A8J8XIG2 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os01g0696800_A2ZWV5_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0696800_Q0JK46_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0728100_A0A0N7KDN9_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0728100_A0A0P0V7N9_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0728100_C7IWV5_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0747750_A0A0P0V865_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0772100_Q5N8Y9_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0778400_A0A0P0V901_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0795000_A0A0N7KDW4_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0795000_Q5ZBR8_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0795200_A0A0P0V9A3_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0795200_Q0JIK5_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0796000_A0A0P0V970_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0800900_A0A0P0V9B1_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0800900_C7IXG9_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0813800_A0A0N7KDY3_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0813800_A0A0P0V9R8_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0814100_A2ZYX7_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0814100_Q8RZK6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0823150_A0A0P0V9T4_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A2ZZP0
# AlphaFold ID A2ZZP0 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os01g0854800_Q5N7U6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0871500_A0A5S6RAJ7_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/Q5N9Z6
# AlphaFold ID Q5N9Z6 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os01g0871600_A0A0P0VAZ6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0887550_A0A0P0VBC3_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0891100_A0A0P0VBN2_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A0A0P0VCN3
# AlphaFold ID A0A0P0VCN3 not found in AlphaFold
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A0A8U0WP26
# AlphaFold ID A0A8U0WP26 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os01g0940700_Q0JG58_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0940700_Q7F164_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0940700_Q9SXY6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0944700_Q94CR1_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0949900_A0A0P0VCX6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0952000_Q942A8_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0952000_A0A0P0VCZ6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0952800_Q0JFZ0_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0952800_A0A0P0VCZ9_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A0A8J8YH56
# AlphaFold ID A0A8J8YH56 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os01g0954100_Q5JJT6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0965800_A0A0P0VD76_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0965800_Q8LHD3_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os01g0973100_A0A0N7KEH6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0121700_Q6ZH94_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0136933_A0A0N7KEN0_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0149900_Q67UX6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0191800_A0A0N7KEU7_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0191800_Q0E364_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0207100_A0A0P0VG84_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0226200_A0A0N7KEY8_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0226200_Q6H6J4_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0240300_Q0E2H3_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0240300_Q6ER49_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A3A543
# AlphaFold ID A3A543 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os02g0251800_Q6KA26_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A3A544
# AlphaFold ID A3A544 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os02g0251900_Q6K544_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0306401_A0A0P0VI36_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A0A0P0VI48
# AlphaFold ID A0A0P0VI48 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os02g0308400_Q6Z0W5_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0504000_A0A0P0VJC6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0508801_A3A792_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0508801_Q6K2G2_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0561100_A0A0P0VKG8_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0563000_A0A0N7KFI1_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0565150_C7IYJ2_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0565150_Q6Z7E4_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0570700_Q6YV88_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0571100_Q6Z5I0_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0571100_C7IY39_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0575200_Q69S81_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0579000_A0A0P0VKT6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0579000_Q0E046_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/Q6EPT6
# AlphaFold ID Q6EPT6 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os02g0584700_Q6YY34_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0594166_A0A0P0VL55_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0594166_C7IYA4_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0594232_A0A0P0VL30_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0594300_Q0DZW9_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0594300_Q6ZH77_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0608000_A0A0P0VLK8_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0616100_A0A0P0VLN2_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0616100_A0A0P0VLS4_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0616100_A0A0P0VLV5_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A0A8J8XG95
# AlphaFold ID A0A8J8XG95 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os02g0616100_B9F131_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0616100_Q6K8U3_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0649900_Q6H3Z6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0650300_Q6H3Z3_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0650300_A0A0N7KFS7_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0650300_C7IYA5_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A0A8J8YD69
# AlphaFold ID A0A8J8YD69 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os02g0684500_Q7XUC9_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0732800_A0A0P0VP97_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0744501_A0A0P0VPJ6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0744501_C7IZ39_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0768400_A0A0P0VQ99_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0779400_A0A0P0VQH5_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0779400_Q6K7G3_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0780000_A0A0N7KG72_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0791400_A0A0P0VQH4_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0791400_Q6KAE3_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0833900_A0A0P0VRR9_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0833900_A0A0P0VRS0_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0833900_Q6EP33_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0833900_Q6EP34_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os02g0833975_A0A0P0VRR6_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A0A8J8Y4W1
# AlphaFold ID A0A8J8Y4W1 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os03g0124900_Q10SE9_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0135200_A0A0P0VSQ7_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0135200_Q0DVD9_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0162200_Q8H7Y8_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0180800_Q8GSI0_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0194600_A0A0P0VU65_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0194600_Q8H7W6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0204900_Q10Q93_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0210200_A0A0P0VUM1_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0237100_Q10PE7_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0261100_Q9XG81_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0293700_A0A0P0VWB6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0307200_Q10MI9_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0307300_Q0DSH9_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0307300_H9BE58_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0322900_A3AHG5_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0332100_Q0DS59_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0341000_Q0DS06_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0341000_Q10LN8_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0371000_A0A0P0VXW6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0372600_A0A0P0VXY2_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0372600_Q84TS2_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0379300_Q10KL8_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0400200_A0A0P0VZ39_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0400200_Q94LE8_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0404800_Q0DR98_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0404800_Q10JX4_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0418000_P25765_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0431600_A0A0P0VZV9_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0431800_A0A0P0VZP7_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0439700_B9F981_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0439700_Q10J01_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0439800_A0A0P0VZS4_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0439800_A0A0P0VZT7_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0439800_Q0DQW9_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0439800_Q75KB8_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0617500_A0A0P0W081_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0617500_A0A0P0W140_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A0A8J8XJA3
# AlphaFold ID A0A8J8XJA3 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os03g0628800_Q10GG7_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0634400_Q75GK4_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0651800_Q7XZY1_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0667300_Q6L8G1_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0725200_A0A0P0W367_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0725200_Q6AU08_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0736900_A0A0P0W3C6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0736900_Q0DNS7_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0751100_A0A0P0W3R8_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/B9FBU7
# AlphaFold ID B9FBU7 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os03g0751100_Q75LM0_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0751200_A0A0P0W3Q5_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0760200_A0A0P0W3D4_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0760200_Q0DND2_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0779300_A0A0P0W4C5_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0804200_A3ANS5_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0804200_Q75HK2_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0833100_A0A0P0W560_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0833100_Q0DM18_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0842501_A0A0P0W5H4_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0859100_A0A0P0W5R9_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A0A8J8XPT0
# AlphaFold ID A0A8J8XPT0 not found in AlphaFold
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A0A8J8YIZ0
# AlphaFold ID A0A8J8YIZ0 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os03g0859100_A3APY6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0859100_A3APY7_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os03g0859100_Q84M86_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A3AQB9
# AlphaFold ID A3AQB9 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os04g0119000_Q7XTJ5_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os04g0119000_Q01MR8_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os04g0121100_A3AQD6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os04g0121100_Q7XT44_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os04g0127100_B7F194_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os04g0179100_A0A0P0W7F3_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os04g0231200_A0A0N7KIP9_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os04g0282400_Q0JEF5_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os04g0302900_A0A0P0W8F2_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os04g0307500_A0A0P0W8E3_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os04g0339800_A0A0P0W9D8_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os04g0340300_B9FEI0_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os04g0340300_Q0JE23_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A3ASQ4
# AlphaFold ID A3ASQ4 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os04g0352200_Q0JDY9_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os04g0381700_A0A0N7KIY3_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os04g0382900_Q7F976_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os04g0382900_Q7XVC6_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/B9FEV0
# AlphaFold ID B9FEV0 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os04g0384800_Q7XL64_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os04g0400000_A0A0N7KJ00_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os04g0405500_A0A0P0W9R7_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os04g0405500_Q0JDG3_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os04g0405500_Q01L40_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os04g0405900_A0A0P0WA01_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os04g0405900_Q0JDF9_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os04g0453200_A0A0P0WBC8_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os04g0453200_Q0JCR8_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os04g0453200_Q7XUX7_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os04g0462550_A0A0P0WB83_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os04g0468600_A0A0P0WBA3_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A0A0P0WBG6
# AlphaFold ID A0A0P0WBG6 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os04g0468600_A0A0P0WBR0_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os04g0468600_B7E663_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os04g0468600_Q7XJV6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os04g0468600_Q01IR6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os04g0493400_O04138_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os04g0494100_Q7Y1Z0_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os04g0494100_A0B9Y6_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/C7J1U9
# AlphaFold ID C7J1U9 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os04g0545300_Q7FAI8_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os04g0545600_A0A0P0WCZ3_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os04g0545600_Q0JBA5_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/Q0JAT2
# AlphaFold ID Q0JAT2 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os04g0578600_A0A0P0WE87_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os04g0587500_A0A0P0WE19_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os04g0609300_Q0JAA2_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os04g0609300_Q7XPE0_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os04g0609300_Q25AI6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os04g0644433_A0A0P0WFM6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os05g0106200_Q0DLE2_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os05g0106200_Q65XI0_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os05g0113900_Q75L11_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os05g0128900_A0A0P0WHK2_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os05g0153500_A0A0P0WI49_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os05g0197200_A0A0P0WJ89_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os05g0201700_A0A0P0WJ93_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os05g0201700_Q6L4Q2_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os05g0349800_P46520_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os05g0349800_A0A0N7KKL2_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/B9FH97
# AlphaFold ID B9FH97 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os05g0360400_Q5KQA8_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os05g0367900_A0A0N7KKM8_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os05g0367900_Q0DIR9_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os05g0372866_A0A0N7KKN4_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/B9FHT0
# AlphaFold ID B9FHT0 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os05g0375400_Q75K72_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os05g0438700_A0A0P0WMX5_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os05g0439100_A0A0P0WMZ5_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os05g0439100_Q0DHU6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os05g0475700_A0A0P0WNL1_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A0A8J8XMT0
# AlphaFold ID A0A8J8XMT0 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os05g0475700_Q0DHC7_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os05g0477666_A0A0N7KKY9_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/Q0DHB4
# AlphaFold ID Q0DHB4 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os05g0478000_Q75GN1_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os05g0482400_Q5KQH7_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os05g0499300_P37834_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os05g0519300_A0A0P0WPI1_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os05g0519300_Q65X09_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os05g0549232_A0A0P0WQ34_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os05g0551000_B7EEC0_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os05g0551000_Q6AUD8_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/B9FHX9
# AlphaFold ID B9FHX9 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os05g0560500_Q688Y6_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A0A8J8XPZ6
# AlphaFold ID A0A8J8XPZ6 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os05g0579600_Q0DFN8_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os05g0582350_A0A0P0WRE4_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os05g0592300_A0A0P0WQP3_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os05g0592300_B9FLW7_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os05g0592300_Q0DFG5_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os06g0112300_Q9LHY9_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os06g0129900_A0A0P0WRU9_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A3B812
# AlphaFold ID A3B812 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os06g0129900_Q658G9_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os06g0148250_A0A0N7KLJ1_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os06g0192100_A0A0P0WU30_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os06g0193200_Q0DDW8_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os06g0193200_Q69Y54_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os06g0210000_A0A0P0WTT2_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os06g0210000_Q69TY0_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os06g0228500_B9FSB3_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os06g0228500_Q67WJ7_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os06g0254600_Q652U5_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os06g0254600_Q656N6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os06g0278000_A0A0P0WVJ8_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os06g0293000_A0A0P0WVF8_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os06g0294950_A0A0P0WVS8_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os06g0294950_C7J397_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os06g0295000_A0A0P0WVH4_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os06g0301400_A0A0P0WVM6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os06g0306300_A0A0P0WVQ3_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os06g0306300_Q0DCP0_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A3BB54
# AlphaFold ID A3BB54 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os06g0316000_Q5Z4Q8_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os06g0473000_A0A0P0WWM6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os06g0518100_A0A0P0WXM6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os06g0539500_A0A0N7KM86_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os06g0539500_Q5Z710_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os06g0542300_A3BCI5_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os06g0542300_Q5Z6Y0_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os06g0549300_A0A0P0WXN6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os06g0560000_Q5Z922_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A0A8J8XX48
# AlphaFold ID A0A8J8XX48 not found in AlphaFold
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A0A8J8YJV4
# AlphaFold ID A0A8J8YJV4 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os06g0574700_B9FTV7_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os06g0574700_B9FTV8_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A3BD70
# AlphaFold ID A3BD70 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os06g0591200_Q69X78_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os06g0636700_A0A0P0WZK7_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os06g0636700_Q67WG1_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os06g0688200_A0A0P0X049_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os06g0694400_B9FQN4_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os06g0694400_Q5Z8I6_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/Q0D9V2
# AlphaFold ID Q0D9V2 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os06g0696600_Q5Z6H0_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A3BF10
# AlphaFold ID A3BF10 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os06g0697600_Q0D9U6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os06g0699100_A0A0P0X0M7_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os06g0718400_A3BFH0_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os06g0718400_Q5Z8N5_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os06g0718400_Q8SB26_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0129200_Q6YSF8_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0142100_Q0D8P1_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0142100_A0A0N7KMX3_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0142200_A0A0P0X2Q0_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0142200_Q8H4K4_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0142300_A0A0P0X258_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0142300_Q7F168_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0142500_A0A0P0X2H1_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0142500_Q8H4K2_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0142600_A0A0P0X282_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0142600_Q0D8N7_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0174900_A3BH27_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0174900_Q8H574_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0179300_Q6ZLD3_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0190000_Q6YU51_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0241500_Q0D7J2_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0241500_Q7XI35_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0251200_A0A0P0X498_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0257200_Q8H4H5_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0257200_I7GYG6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0258100_A0A0P0X591_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0258400_Q0D7E4_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0258400_A0A0P0X4D2_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0258400_A0A1Y1B854_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0258501_A0A0P0X485_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0292100_A0A0P0X5B5_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0417600_A0A0P0X4W3_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0417600_Q8GVI7_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0429700_A0A0P0X5M8_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0429700_Q6ZL66_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0432333_A0A0P0X520_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0432333_Q6YTL9_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0516700_A0A0P0X717_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A3BKC7
# AlphaFold ID A3BKC7 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os07g0524200_A0A0P0X782_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0524200_Q69SA8_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0524900_Q69SA4_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/Q69UC2
# AlphaFold ID Q69UC2 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os07g0529600_Q7XXS4_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0529600_A0A0N7KNK4_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0561800_A0A0P0X7B4_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0561800_A0A0P0X7T0_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0561800_Q0D5H2_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0593000_A3BLS1_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0593000_Q84RX1_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A3BLW4
# AlphaFold ID A3BLW4 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os07g0600200_Q8H596_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A3BLZ5
# AlphaFold ID A3BLZ5 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os07g0604700_Q6Z4G4_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0622700_Q0D4J2_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0622700_Q7XI46_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0624600_Q7XI41_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0664000_A0A0P0XA14_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0687400_A3BNL0_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0687400_Q8LIG1_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0693800_A0A0P0XAP2_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/Q0D3C6
# AlphaFold ID Q0D3C6 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os07g0693800_Q7XI61_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os07g0693800_Q84NP3_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A3BNS5
# AlphaFold ID A3BNS5 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os08g0101100_Q6Z1Z2_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os08g0102250_A0A0P0XAU6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os08g0111200_A0A0P0XBA7_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os08g0111200_Q6ZC53_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os08g0111200_Q6ZCE0_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os08g0167800_A0A0P0XC15_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os08g0189300_Q6YZZ6_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A3BQJ9
# AlphaFold ID A3BQJ9 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os08g0201100_Q6Z1A0_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os08g0300366_A0A0P0XER8_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os08g0346900_A0A0P0XEP6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os08g0347000_A0A0P0XEW0_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os08g0348300_A0A0N7KPQ2_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os08g0455900_Q6Z0Q9_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os08g0455900_F5BCS2_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os08g0462900_A0A0P0XGS9_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os08g0462900_Q6YUB6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os08g0535000_Q6YZF6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os08g0535000_Q6Z1H9_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os08g0547300_Q0J3X3_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os08g0547300_Q6Z9D5_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os08g0547800_A0A0P0XIE0_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os08g0547800_Q6YSZ8_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os09g0110300_Q6YX89_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os09g0129500_A0A0P0XJZ9_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os09g0129600_A0A0P0XKA3_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os09g0129800_A0A0P0XKQ7_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os09g0129800_Q6ERA9_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os09g0130300_A0A0P0XKZ4_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os09g0246300_A0A0P0XKQ1_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os09g0249750_A0A0P0XK13_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os09g0271100_A0A0P0XJB3_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os09g0271100_B9G2H5_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os09g0271100_Q0J315_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os09g0272900_A0A0P0XJA5_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A3BWR6
# AlphaFold ID A3BWR6 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os09g0272900_Q6H4Y5_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os09g0275400_A0A0P0XL69_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os09g0275400_Q6H4B5_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os09g0325000_A0A0N7KQK5_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A3BYZ6
# AlphaFold ID A3BYZ6 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os09g0424300_Q6F4N6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os09g0424401_A0A0N7KQU0_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os09g0442600_Q67UU0_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os09g0443800_A0A0P0XMF4_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os09g0451400_Q0J1C1_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os09g0472700_A0A0P0XN12_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os09g0472900_A0A0P0XPD7_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os09g0472900_Q0J103_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os09g0511200_A0A0P0XNZ0_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os09g0517900_A0A0P0XP54_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os09g0517900_Q69JH3_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os09g0518200_Q0J0B6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os09g0518200_Q69IV0_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os09g0519100_A0A0P0XQ00_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os09g0528700_A0A0P0XQ01_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os09g0528700_Q69NG7_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os09g0547033_A0A0P0XPZ8_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os09g0551600_Q0IZT2_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os09g0551600_Q69MM2_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os09g0554200_A0A0P0XRD9_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os09g0554200_Q0IZR5_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os09g0567500_A0A0P0XQF8_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os09g0567500_A0A0P0XQL4_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os09g0567500_Q0IZI9_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os10g0144700_A0A0P0XRF4_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os10g0148100_A0A5S6RAZ4_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os10g0148100_Q7XGT9_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/Q0IYX5
# AlphaFold ID Q0IYX5 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os10g0150700_Q7XGS3_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A3C2L3
# AlphaFold ID A3C2L3 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os10g0150800_Q7XGS2_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os10g0160700_A0A0P0XSL2_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os10g0160700_C7J7U7_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A0A8J8XL12
# AlphaFold ID A0A8J8XL12 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os10g0165300_Q10A28_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os10g0180800_A0A0P0XS59_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os10g0180800_Q0IYQ2_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os10g0180800_Q10A19_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os10g0180800_Q33AH5_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A0A8J8XYP0
# AlphaFold ID A0A8J8XYP0 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os10g0195250_B9G7W2_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A0A0P0XTI8
# AlphaFold ID A0A0P0XTI8 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os10g0349300_Q8LM52_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os10g0397900_Q338K5_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os10g0436900_Q0IXH8_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os10g0436900_Q337V5_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A0A8J8XYL6
# AlphaFold ID A0A8J8XYL6 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os10g0456100_Q7XDQ8_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os10g0463200_Q0IX65_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os10g0463200_Q7XDM8_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os10g0472900_Q7G7W2_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os10g0472900_Q9FW59_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os10g0475000_A0A0P0XV85_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os10g0475000_C7J815_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os10g0475100_A0A0P0XVN3_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os10g0478000_Q7XDD0_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os10g0489500_A0A0P0XWI8_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os10g0490400_A0A0P0XVL6_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A0A8J8YML7
# AlphaFold ID A0A8J8YML7 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os10g0490800_Q7XD55_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os10g0508700_Q0IWH6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os10g0508700_Q8LN75_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/Q7G7F4
# AlphaFold ID Q7G7F4 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os10g0527800_Q945W6_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/Q7G7F5
# AlphaFold ID Q7G7F5 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os10g0528300_Q9FUE4_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os10g0530900_Q06398_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os10g0530900_A0A0P0XXH4_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os10g0531400_A3C6R3_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os10g0531400_Q8L4V6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os10g0545500_A0A0P0XWT6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os10g0552800_A3C756_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os10g0552800_Q9FWP9_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os10g0555700_O24230_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os10g0556000_A0A0P0XXI3_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os10g0570200_B9G745_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os10g0570200_Q7G1N7_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/Q0IVE2
# AlphaFold ID Q0IVE2 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os10g0576600_Q336P1_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os10g0576600_Q7XBV4_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os10g0578800_A0A0P0XXY0_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os10g0578800_A0A5S6RAY3_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os10g0578800_Q7XBT7_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A0A8J8XX60
# AlphaFold ID A0A8J8XX60 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os11g0134900_Q2RAW8_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os11g0151500_A0A0P0XZC7_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os11g0151500_Q0IUK3_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os11g0153500_A0A0P0XYX9_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os11g0153500_Q53LV0_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os11g0154900_A0A0N7KSG4_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/C7J860
# AlphaFold ID C7J860 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os11g0161200_Q53PM1_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os11g0170900_A0A0P0XZM0_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os11g0210600_A0A0N7KSL8_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os11g0210600_Q0ITW6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os11g0214900_A3C9Q6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os11g0214900_Q2R8V8_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/Q0ITL6
# AlphaFold ID Q0ITL6 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os11g0241700_Q53Q17_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os11g0262600_Q0ITF6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os11g0262600_Q9FRT1_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os11g0286800_A0A0P0Y167_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os11g0286800_A0A0P0Y196_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os11g0286800_A0A0P0Y1B3_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os11g0286800_A0A0P0Y1C0_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os11g0286800_Q0IT98_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os11g0439600_A0A0P0Y1S8_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os11g0439600_Q53KM3_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os11g0592200_A3CCY3_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os11g0592200_Q941F5_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os11g0600500_A3CCT1_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os11g0600500_Q2R1L7_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os11g0641500_Q2R0L2_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os11g0649500_Q0IRC6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os11g0649500_Q2R0D3_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os11g0649600_Q2R0D2_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os11g0649700_Q2R0D1_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os11g0655900_Q2R076_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os11g0687200_A0A0P0Y5F2_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os11g0687200_B7F036_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os11g0687200_Q0IR20_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os11g0687200_Q2QZH2_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os12g0116800_A0A0P0Y6C0_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os12g0123500_Q2QYE1_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os12g0132500_A0A0P0Y6P8_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os12g0191601_A3CFN2_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os12g0191601_Q2QWL6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os12g0194900_Q0IPJ3_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os12g0194900_Q2QWH7_info.json already exists
# Request failed: 404 Client Error: Not Found for url: https://alphafold.ebi.ac.uk/api/prediction/A0A8J8YQ77
# AlphaFold ID A0A8J8YQ77 not found in AlphaFold
# ../out/rice_down/rice_down_afinfo/Os12g0221400_Q2QVQ8_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os12g0222300_Q0IPC9_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os12g0222300_Q2QVP7_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os12g0236100_A0A0P0Y8Q6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os12g0236225_A0A0P0Y8I6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os12g0239900_A0A0P0Y8I2_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os12g0282000_Q0INX0_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os12g0282000_Q2QTV2_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os12g0441600_A0A0P0Y9M0_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os12g0472500_Q2QR54_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os12g0505800_A0A0P0YAF6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os12g0508500_Q2QQ32_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os12g0512100_Q0IN24_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os12g0512100_Q2QPZ5_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os12g0555000_A3CIB9_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os12g0555000_Q75T45_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os12g0555200_Q0IMQ1_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os12g0555200_Q2QNT0_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os12g0555500_B9GDP9_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os12g0555500_Q2QNS7_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os12g0555500_Q40707_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os12g0571400_C7J9X9_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os12g0571400_Q2QNC0_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os12g0599700_A0A0P0YBZ0_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os12g0601800_A0A0N7KUB6_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os12g0610800_Q0ILZ7_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os12g0610800_A0A0N7KUC5_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os12g0630100_Q0ILR1_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os12g0630100_Q2QLS8_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os12g0630200_A3CJP3_info.json already exists
# ../out/rice_down/rice_down_afinfo/Os12g0630200_Q2QLS7_info.json already exists

# %% [markdown]
# ## 5. Download mmCIF files

# %%
# !bash ../scripts/afurl_download.sh ../out/rice_down/rice_down_afinfo/ ../out/rice_down/rice_down_mmcif/
# Out:
# File ../out/rice_down/rice_down_mmcif//AF-Q7G7W2-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0V528-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q69MM2-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0X4W3-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0V5L9-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0V3I1-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q8LRI2-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0VAZ6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q7XDM8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6Z7E4-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XQ01-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0X5B5-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0W8F2-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q67UX6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q2R1L7-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0V9T4-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q5Z6H0-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q5ZBR8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q337V5-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0B9Y6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0JCR8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q10MI9-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0N7KSG4-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0Y167-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-B7F036-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q8GSI0-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q2R0L2-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0J0B6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q656N6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0DVD9-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q2R076-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-P46520-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-B7F194-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q10Q93-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-C7J397-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0W081-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0N7KKY9-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0WBR0-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XEW0-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6H6J4-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0JIK5-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0N7KEN0-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A3BNL0-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0X591-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0VP97-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q10KL8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q67WG1-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0VZT7-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6YU51-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q7XJV6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-C7IYA5-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0V0L5-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0WWM6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0VXY2-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XYX9-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-C7IYJ2-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q8H4K4-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0V2W9-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-O04138-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0WBC8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q2QVQ8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0DHC7-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q75KB8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0X520-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0V865-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0Y196-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XIE0-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0VL30-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0N7KKN4-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0JAA2-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A5S6RAZ4-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-I7GYG6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0N7KDN9-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XKZ4-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-C7IYA4-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XER8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0D7J2-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A5S6RAJ7-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0N7KIP9-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q7XGS3-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q7Y1Z0-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XXI3-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A3ANS5-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XQ00-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q5QLE7-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0WVQ3-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q8H7Y8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0VWB6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q7G1N7-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0VCZ9-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0V9A3-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0E2H3-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-C7IXE8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XNZ0-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q2QQ32-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0D8P1-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q53Q17-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q8RZK6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0WMX5-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q2QLS8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0VRS0-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6YX89-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A3C9Q6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q5N7U6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6YV88-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0DHU6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q9FRT1-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-B9FQN4-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0JE23-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0D4J2-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q69S81-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q10LN8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0IWH6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q9FTI3-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0VSQ7-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q7XTJ5-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q2QNT0-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0X717-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-B9GDP9-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q2R0D3-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0W367-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0W9R7-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XVL6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-B9FEI0-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q7XL64-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q69JH3-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XBA7-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6YUB6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q8H596-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-B9F131-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q10A28-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q7XT44-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A3APY7-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0E046-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0WXM6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0YBZ0-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0VRR9-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q5Z6Y0-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0WA01-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q7F4M8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q5Z710-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XXY0-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6ERA9-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-C7IY39-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6YSF8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XWT6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0VLN2-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0VQH5-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q9FWP9-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6ER49-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A3CCY3-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q658G9-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6F4N6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q9FU17-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0IT98-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6AU08-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q10J01-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q84TS2-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q7F1Q9-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0Y8I6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-O24220-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0W140-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A3AHG5-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XSL2-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0IPJ3-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XZC7-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0D9U6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0WXN6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q7XXQ7-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A2ZYX7-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q5Z8N5-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0N7KDY3-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0VRR6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0DS59-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0N7KFI1-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0W5H4-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0IUK3-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q2R0D2-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-B9G7W2-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0IZR5-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q7XI46-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q5JJT6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0V5W5-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-F5BCS2-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q338K5-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XRF4-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q7XXS4-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q2QNC0-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q5Z4Q8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0JG58-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q84RX1-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XL69-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q7F168-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q7XD55-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0N7KD90-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6L8G1-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0VXW6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q75K72-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6ZL66-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-B9FTV8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0N7KEH6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-O22080-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q75L11-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0W8E3-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q75GK4-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0X7B4-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q9SXY6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6ZH77-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0VBC3-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A3BFH0-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q5KQA8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6K544-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0N7KSL8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0W3Q5-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q8H574-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0VPJ6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A3C756-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A3BLS1-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0WHK2-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0VI36-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q7F731-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-C7IZ39-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q7XGT9-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0IZI9-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0N7KDW4-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q8LN75-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0WNL1-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6KAE3-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q7F976-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q84NP3-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0IYQ2-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XJZ9-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0X5M8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q8L4V6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0N7KKL2-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0Y9M0-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0N7KJ00-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0ITF6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q7F2N5-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0W9D8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0WE87-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XJB3-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q9LHW4-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0WJ89-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XN12-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q7XBV4-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q69X78-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6H4Y5-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-C7IXG9-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6ZLD3-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0N7KQU0-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q9XG81-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6H4B5-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q5ZC68-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0VBN2-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-B7E663-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q2R0D1-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0WQ34-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6YTL9-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0VKG8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0X782-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-C7J9X9-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6Z1H9-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0N7KQK5-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q652U5-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-V9G2Z0-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q2QTV2-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6Z4G4-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0YAF6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0N7KUB6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q7XZY1-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A3C6R3-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q941F5-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-C7IWV5-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6K8U3-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q7F164-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6Z0Q9-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0V1T5-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q8GVI7-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A3CCT1-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XRD9-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0IZT2-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0DFN8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q8H4H5-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0V4Q5-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A3APY6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6L4Q2-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0UZP7-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A3A792-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q7FAI8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0DM18-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0ITW6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0DR98-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6ZC53-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0IXH8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0Y8Q6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XK13-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6K2G2-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q7XPE0-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q69Y54-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6H3Z3-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0VLV5-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q01IR6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0N7KMX3-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0WU30-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0WI49-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0E364-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q2QZH2-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6AUD8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0DDW8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q10A19-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0VL55-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6EP34-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q8RZJ7-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0N7KLJ1-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q8H7W6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6YSZ8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0W7F3-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q8LM52-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q2QLS7-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0JEF5-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q53KM3-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0V901-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q2QWH7-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0JDF9-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-B7EEC0-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XVN3-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0W3R8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q7XI35-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0J1C1-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q5N8Y9-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0V637-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6Z1A0-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0D8N7-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q69IV0-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0N7KEY8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q25AI6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0V521-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-B7FAP2-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q67WJ7-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0DLE2-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0W560-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0JDY9-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XS59-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q7XVC6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6Z1Z2-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XWI8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0DND2-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XJA5-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q69SA8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0IRC6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q9LHY9-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0JDG3-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XC15-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q8LHD3-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6Z0W5-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0VZS4-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0Y1C0-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q7XDQ8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0DSH9-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0WRE4-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0Y6C0-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A3CIB9-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0VJC6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A5S6RAY3-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q9XHX6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A3CJP3-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q2QVP7-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0DFG5-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0N7KKM8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-B9F981-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XKA3-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q8H6D6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q688Y6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0JN44-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-P37834-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q53PM1-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q5Z8I6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q5JK80-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XGS9-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0WPI1-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0Y6P8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0WE19-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0X0M7-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q8H4K2-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q5Z922-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q94CR1-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0Y5F2-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q7F7C9-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q7XGS2-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q7XDD0-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6ZCE0-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A2ZWV5-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-C7J7U7-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0N7KDK3-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0VG84-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0JK46-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0N7KFS7-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XAU6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q9FUE4-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q65X09-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0Y8I2-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0DNS7-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6Z9D5-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q33AH5-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0WMZ5-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0VD76-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q06398-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q84M86-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0D7E4-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-B9FSB3-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0DIR9-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0N7KM86-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q7XBT7-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q7XUX7-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0DS06-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0V7N9-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q2QNS7-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0V5H0-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q7XUC9-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6Z5I0-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0WCZ3-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0J103-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q69SA4-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0WVF8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0WVM6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0V376-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0JFZ0-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q5NBS2-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0WJ93-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0X498-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q75HK2-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q69TY0-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q01MR8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-O04000-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q2QPZ5-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0WB83-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0Y1B3-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0UWX1-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A1Y1B854-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-C7IWA4-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-B9FTV7-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0DQW9-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0IX65-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6KA26-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0N7KG72-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0VCX6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-B9G2H5-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0V9R8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XA14-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0UXR3-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q67UU0-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-O24230-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0N7KUC5-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q9FW59-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q5SN79-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-P25765-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A3BCI5-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-C7J815-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0X2H1-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0W3D4-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6K7G3-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A3CFN2-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0VU65-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0WVS8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q2RAW8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q10GG7-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0JQ63-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0VZP7-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0X4D2-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q2QYE1-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0VLK8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XEP6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q53LV0-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0X282-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q2R8V8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q10JX4-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XPD7-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0WBA3-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0WTT2-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0X7T0-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XQF8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0WZK7-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0WQP3-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6YY34-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0W3C6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0J315-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XKQ7-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0WRU9-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0X485-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A3BH27-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q336P1-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0IN24-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XZM0-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q2QR54-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0N7KIY3-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0N7KDF8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6YZZ6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0W4C5-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0VQ99-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XV85-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0N7KDJ4-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6EP33-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XMF4-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A3AQD6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0IPC9-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XQL4-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0VUM1-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q8LIG1-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0X258-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q40707-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0VZ39-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XPZ8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0J3X3-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0JN80-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0V9B1-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q75T45-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0N7KNK4-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q10SE9-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0Y1S8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0JBA5-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0VQH4-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0WFM6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XKQ1-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q69NG7-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0X049-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-B9G745-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q942A8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0VKT6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-H9BE58-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0V569-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XXH4-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0WVJ8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0D5H2-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q9LWR2-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0V2D0-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0VZV9-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q10PE7-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0ILZ7-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q945W6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6ZH94-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0ILR1-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-B9FLW7-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0N7KPQ2-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0VLS4-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0IR20-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XAP2-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q75LM0-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0IMQ1-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0N7KEU7-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0WVH4-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0XP54-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q7XI41-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0X2Q0-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q75GN1-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q7XI61-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0INX0-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q94JC6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q65XI0-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0V970-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0DCP0-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q5KQH7-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6H3Z6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q6YZF6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q01L40-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q8W084-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q2QWL6-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q94LE8-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q8SB26-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0W5R9-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-Q0DZW9-F1-model_v4.cif already exists. Skipping download.
# File ../out/rice_down/rice_down_mmcif//AF-A0A0P0VCZ6-F1-model_v4.cif already exists. Skipping download.

# %% [markdown]
# ## 6. Save all results

# %%
unmapped_df.write_csv("../out/rice_down/rice_down_unmapped_idmapping.tsv", separator="\t")
id_mapping_df.write_csv("../out/rice_down/rice_down_idmapping.tsv", separator="\t")
