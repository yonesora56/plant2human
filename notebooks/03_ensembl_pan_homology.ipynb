# %%
import glob
import requests
import json
import polars as pl
import time
import datetime
import pathlib
from datetime import datetime

# %%
VERSION = datetime.now().strftime("%y%m%d")
print(VERSION)
# Out:
# 241005

# %%
def get_pan_homology(dataframe: pl.DataFrame, query_taxon: str, target_taxon: int, result_dir: str, no_homology_file: str):
    """
    Get pan-homology data from Ensembl and save as JSON files.
    """
    pathlib.Path(result_dir).mkdir(parents=True, exist_ok=True)
    
    # no homology gene id information
    no_homology_file_path = pathlib.Path(result_dir) / no_homology_file
    if no_homology_file_path.exists():
        with open(no_homology_file_path, "r", encoding="utf-8") as f:
            no_homology_genes = set(f.read().splitlines())
    else:
        no_homology_genes = set()

    for row in dataframe.iter_rows():
        gene_id = row[0]
        json_file_name = pathlib.Path(result_dir) / f'{gene_id}_pan_homology_{target_taxon}.json'
        
        
        if json_file_name.exists():
            message1 = f"{json_file_name} already exists"
            print(message1)
            continue
        
        
        if gene_id in no_homology_genes:
            message2 = f"No pan-homology information found for {gene_id} (previously recorded)"
            print(message2)
            continue
        
        # example url: https://rest.ensembl.org/homology/id/oryza_sativa/Os01g0136200?compara=pan_homology&content-type=application/json;target_taxon=9606
        request_url = (
            f"https://rest.ensembl.org/homology/id/{query_taxon}/{gene_id}?"
            f"compara=pan_homology&content-type=application/json;target_taxon={target_taxon}"
        )

        try:
            response = requests.get(request_url, headers={"Accept": "application/json"}, timeout=30)
            response.raise_for_status()

            if response.status_code == 200:
                data = json.loads(response.text)
                if data.get("data") and any(d.get("homologies") for d in data["data"]):
                    with open(json_file_name, "w", encoding="utf-8") as f:
                        json.dump(data, f, indent=4)
                    message3 = f"Saved {json_file_name}"
                    print(message3)
                else: # e.g. {data:[{id: "Os01g0136200", homologies:[]}]}
                    no_homology_genes.add(gene_id) # add gene_id to the text file
                    message4 = f"No homology information found for {gene_id}"
                    print(message4)
            else:
                message5 = f"Failed to fetch data for {gene_id}"
                print(message5)
        except requests.exceptions.RequestException as e:
            message6 = f"Request failed: {e}"
            print(message6)
        finally:
            time.sleep(5)
    
    # write no pan-homology information gene id 
    no_homology_df = pl.DataFrame({"From": list(no_homology_genes)})
    no_homology_df.write_csv(no_homology_file_path, separator="\t")

# %%
def process_json_files(result_dir: str, output_file: str):
    """
    Process JSON files in the result directory and return a dataframe.
    """
    json_files = glob.glob(str(pathlib.Path(result_dir) / "*.json"))
    
    dataframe = []
    
    for file in json_files:
        df = pl.read_json(file).explode("data").unnest("data").rename({"id": "From"}).explode(
            "homologies"
        ).unnest("homologies").unnest("source").rename(
            {
                "perc_pos": "source_perc_pos",
                "perc_id": "source_perc_id",
                "cigar_line": "source_cigar_line",
                "protein_id": "source_protein_id",
                "taxon_id": "source_taxon_id",
                "align_seq": "source_align_seq",
                "id": "source_id",
                "species": "source_species"
            }
        ).unnest("target").rename(
            {
                "perc_pos": "target_perc_pos",
                "perc_id": "target_perc_id",
                "cigar_line": "target_cigar_line",
                "protein_id": "target_protein_id",
                "taxon_id": "target_taxon_id",
                "align_seq": "target_align_seq",
                "id": "target_id",
                "species": "target_species"
            }
        )
        # add data to dataframe
        dataframe.append(df)
    
        
    combined_df = pl.concat(dataframe, how="diagonal_relaxed").sort(
        ["From"], descending=False
    ).select(
        [
            "From",
            "method_link_type",
            "type",
            #"taxonomy_level"
            "source_id",
            "target_id",
            "source_protein_id",
            "target_protein_id",
            "source_perc_pos",
            "target_perc_pos",
            "source_perc_id",
            "target_perc_id"
            # "source_align_seq",
            # "target_align_seq",
            # "source_cigar_line",
            # "target_cigar_line",
            # "dn_ds",
            # "source_taxon_id",
            # "target_taxon_id",
            # "source_species",
            # "target_species",
        ]
    ).sort(
        ["From", "source_perc_id"], descending=[False, False]
    )

    combined_df.write_csv(
        pathlib.Path(result_dir).parent / output_file,
        separator="\t",
    )

# %%
rice_gene_df = pl.read_csv(
    "../Data/Data_HN5_genelist_rice_2402/HN5_genes_down_rice.tsv",
    separator="\t"
).select(
    "From"
).unique().sort(
    "From", 
    descending=False
)

display(rice_gene_df)
# Out:
# shape: (370, 1)
# ┌──────────────┐
# │ From         │
# │ ---          │
# │ str          │
# ╞══════════════╡
# │ Os01g0105300 │
# │ Os01g0136300 │
# │ Os01g0137950 │
# │ Os01g0179600 │
# │ Os01g0192900 │
# │ …            │
# │ Os12g0599700 │
# │ Os12g0601800 │
# │ Os12g0610800 │
# │ Os12g0630100 │
# │ Os12g0630200 │
# └──────────────┘

# %%
get_pan_homology(rice_gene_df, "oryza_sativa", 9606, "../out/rice_down/rice_down_pan_homology/", "rice_down_no_homology_genes.tsv")
# Out:
# No pan-homology information found for Os01g0105300 (previously recorded)
# No pan-homology information found for Os01g0136300 (previously recorded)
# No pan-homology information found for Os01g0137950 (previously recorded)
# ../out/rice_down/rice_down_pan_homology/Os01g0179600_pan_homology_9606.json already exists
# ../out/rice_down/rice_down_pan_homology/Os01g0192900_pan_homology_9606.json already exists
# No pan-homology information found for Os01g0208400 (previously recorded)
# ../out/rice_down/rice_down_pan_homology/Os01g0216000_pan_homology_9606.json already exists
# No pan-homology information found for Os01g0220700 (previously recorded)
# ../out/rice_down/rice_down_pan_homology/Os01g0232000_pan_homology_9606.json already exists
# No pan-homology information found for Os01g0248300 (previously recorded)
# No pan-homology information found for Os01g0248701 (previously recorded)
# ../out/rice_down/rice_down_pan_homology/Os01g0279400_pan_homology_9606.json already exists
# No pan-homology information found for Os01g0284500 (previously recorded)
# No pan-homology information found for Os01g0318400 (previously recorded)
# No pan-homology information found for Os01g0329000 (previously recorded)
# No pan-homology information found for Os01g0329075 (previously recorded)
# ../out/rice_down/rice_down_pan_homology/Os01g0382000_pan_homology_9606.json already exists
# ../out/rice_down/rice_down_pan_homology/Os01g0382400_pan_homology_9606.json already exists
# No pan-homology information found for Os01g0444100 (previously recorded)
# No pan-homology information found for Os01g0495701 (previously recorded)
# No pan-homology information found for Os01g0525701 (previously recorded)
# No pan-homology information found for Os01g0550800 (previously recorded)
# ../out/rice_down/rice_down_pan_homology/Os01g0591300_pan_homology_9606.json already exists
# No pan-homology information found for Os01g0608000 (previously recorded)
# No pan-homology information found for Os01g0608101 (previously recorded)
# ../out/rice_down/rice_down_pan_homology/Os01g0613500_pan_homology_9606.json already exists
# No pan-homology information found for Os01g0627400 (previously recorded)
# No pan-homology information found for Os01g0631800 (previously recorded)
# ../out/rice_down/rice_down_pan_homology/Os01g0631900_pan_homology_9606.json already exists
# No pan-homology information found for Os01g0647200 (previously recorded)
# ../out/rice_down/rice_down_pan_homology/Os01g0655500_pan_homology_9606.json already exists
# No pan-homology information found for Os01g0660200 (previously recorded)
# No pan-homology information found for Os01g0680650 (previously recorded)
# No pan-homology information found for Os01g0689451 (previously recorded)
# ../out/rice_down/rice_down_pan_homology/Os01g0696800_pan_homology_9606.json already exists
# ../out/rice_down/rice_down_pan_homology/Os01g0728100_pan_homology_9606.json already exists
# No pan-homology information found for Os01g0747750 (previously recorded)
# No pan-homology information found for Os01g0772100 (previously recorded)
# No pan-homology information found for Os01g0778400 (previously recorded)
# ../out/rice_down/rice_down_pan_homology/Os01g0795000_pan_homology_9606.json already exists
# ../out/rice_down/rice_down_pan_homology/Os01g0795200_pan_homology_9606.json already exists
# No pan-homology information found for Os01g0796000 (previously recorded)
# No pan-homology information found for Os01g0800900 (previously recorded)
# ../out/rice_down/rice_down_pan_homology/Os01g0813800_pan_homology_9606.json already exists
# No pan-homology information found for Os01g0814100 (previously recorded)
# No pan-homology information found for Os01g0823150 (previously recorded)
# No pan-homology information found for Os01g0854800 (previously recorded)
# ../out/rice_down/rice_down_pan_homology/Os01g